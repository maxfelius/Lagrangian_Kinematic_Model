# %% [markdown]
# # Notebook for plotting Graphs from Baer 2018
#
# This website is used to convert a picture of a graph to actual data
# https://apps.automeris.io/wpd/
#
# 3 datasets are plotted in this notebook:
# - Baer 2018 1
# - Baer 2018 2
# - Baer 2018 3

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys,os,time
import re, datetime

# %% [markdown]
# ## Baer 2018 1
#
# ![](dataset/Baer2018_1.png)

# %%
folder = 'Dataset/Baer2018_1'

dataset_locations = []
for item in os.listdir(folder):
    if item.endswith('.csv'):
        dataset_locations.append(item)


#sort the datasets
dataset_locations = sorted(dataset_locations)

#filter out the datas from the dataset locations
dates_str = list(map(lambda x:re.findall(r"[111214-]\d{6}",x)[0][1:],dataset_locations))

# #converts string dates to datetime objects
dates = list(map(lambda x: datetime.datetime.strptime(x,'%y%m%d'),dates_str))
# Out:
# ['111230', '120216', '120303', '120319', '120404', '120420', '120506', '120522', '120607', '120623']

# %%
# %matplotlib inline

#load the data into a list with panda objects
data_list = []

for date,item in zip(dates_str,dataset_locations):
    temp = pd.read_csv(os.path.join(folder,item),header=None,names=['x',date])
    data_list.append(temp)
    
plt.figure(figsize=(15,10))

for date,item in zip(dates_str,data_list):
    plt.scatter(item['x'],item[date],label=date)
    
plt.grid(True)
plt.ylabel('Vertical Deformation (cm)')
plt.xlabel('Distance (m)')
plt.legend();

# %% [markdown]
# ## Baer 2018 2
#
# ![](dataset/Baer2018_2.png)

# %%
folder = 'Dataset/Baer2018_2'

dataset_locations = []
for item in os.listdir(folder):
    if item.endswith('.csv'):
        dataset_locations.append(item)


#sort the datasets
dataset_locations = sorted(dataset_locations)

#filter out the datas from the dataset locations
dates_str = list(map(lambda x:re.findall(r"[140617-]\d{6}",x)[0][1:],dataset_locations))

# #converts string dates to datetime objects
dates = list(map(lambda x: datetime.datetime.strptime(x,'%y%m%d'),dates_str))

# %%
#load the data into a list with panda objects
data_list = []

for date,item in zip(dates_str,dataset_locations):
    temp = pd.read_csv(os.path.join(folder,item),header=None,names=['x',date])
    data_list.append(temp)
    
plt.figure(figsize=(15,10))

for date,item in zip(dates_str,data_list):
    plt.scatter(item['x'],item[date],label=date)
    
plt.grid(True)
plt.ylabel('Vertical Deformation (cm)')
plt.xlabel('Distance (m)')
plt.legend();

# %% [markdown]
# ## Baer 2018 3
#
# ![](dataset/Baer2018_3.png)

# %%
folder = 'Dataset/Baer2018_3'

dataset_locations = []
for item in os.listdir(folder):
    if item.endswith('.csv'):
        dataset_locations.append(item)


#sort the datasets
dataset_locations = sorted(dataset_locations)

#filter out the datas from the dataset locations
dates_str = list(map(lambda x:re.findall(r"[150519_]\d{6}",x)[0][1:],dataset_locations))

# #converts string dates to datetime objects
dates = list(map(lambda x: datetime.datetime.strptime(x,'%y%m%d'),dates_str))
# Out:
# ['150604', '150620', '150706', '150722']

# %%
#load the data into a list with panda objects
data_list = []

for date,item in zip(dates_str,dataset_locations):
    temp = pd.read_csv(os.path.join(folder,item),header=None,names=['x',date])
    data_list.append(temp)
    
plt.figure(figsize=(15,10))

for date,item in zip(dates_str,data_list):
    plt.scatter(item['x'],item[date],label=date)
    
plt.grid(True)
plt.ylabel('Vertical Deformation (cm)')
plt.xlabel('Distance (m)')
plt.legend();
